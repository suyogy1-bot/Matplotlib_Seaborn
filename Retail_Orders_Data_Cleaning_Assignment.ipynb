# %% [markdown]
# # Retail Orders - Data Cleaning Assignment
# Dataset: messy_retail_orders.csv (synthetic)
#
# Topics: Pandas (Data Cleaning) + Matplotlib + Seaborn
#
# Note: This dataset is intentionally messy - it has missing values, inconsistent
# text casing/spacing, invalid numeric values, duplicate rows, and an OrderDate
# column with several different date formats (and some invalid/missing dates).
# Read every question carefully before writing code.

# %% [markdown]
# ## Part A - Initial Exploration

# %% [markdown]
# ### Q1. Import pandas and load messy_retail_orders.csv.

# %% [markdown]
# ### Q2. Display the first 10 rows.

# %% [markdown]
# ### Q3. Print the shape and column names.

# %% [markdown]
# ### Q4. Use info() to check data types of every column.

# %% [markdown]
# ### Q5. Use describe() to check numeric columns (include='all' to also see text columns).

# %% [markdown]
# ### Q6. Count missing values in every column.

# %% [markdown]
# ### Q7. Show the percentage of missing values in every column.

# %% [markdown]
# ### Q8. Check how many exact duplicate rows exist.

# %% [markdown]
# ## Part B - Cleaning Text Columns

# %% [markdown]
# ### Q9. Check the unique values in the Gender column. You should notice inconsistent casing and extra spaces.

# %% [markdown]
# ### Q10. Clean the Gender column so it only has two values: 'Male' and 'Female'.

# %% [markdown]
# ### Q11. Check the unique values in the CustomerName column. You should notice extra spaces and inconsistent casing.

# %% [markdown]
# ### Q12. Clean CustomerName: remove extra leading/trailing spaces and convert to Title Case.

# %% [markdown]
# ### Q13. Check the unique values in the City column. Some values are missing.

# %% [markdown]
# ### Q14. Fill missing City values with the text 'Unknown'.

# %% [markdown]
# ### Q15. Check the unique values in PaymentMethod. Fill missing values with the most frequent (mode) payment method.

# %% [markdown]
# ## Part C - Cleaning Numeric Columns

# %% [markdown]
# ### Q16. Check the Age column for invalid values (for example negative ages or ages above 90).

# %% [markdown]
# ### Q17. Replace invalid Age values (negative or above 90) with NaN.

# %% [markdown]
# ### Q18. Fill missing Age values with the median Age.

# %% [markdown]
# ### Q19. Check the Quantity column for invalid values (zero or negative quantities).

# %% [markdown]
# ### Q20. Remove rows where Quantity is zero or negative.

# %% [markdown]
# ### Q21. Check missing values in the Price column.

# %% [markdown]
# ### Q22. Fill missing Price values with the median Price of the same ProductCategory (hint: use groupby + transform).

# %% [markdown]
# ### Q23. Check the Discount column for any invalid (negative) values and replace them with 0.

# %% [markdown]
# ### Q24. Check the Rating column for values outside the valid range of 1 to 5, and fix or remove them.

# %% [markdown]
# ### Q25. Fill remaining missing Rating values with the average Rating.

# %% [markdown]
# ## Part D - Cleaning the OrderDate Column

# %% [markdown]
# ### Q26. Print 20 random values from the OrderDate column. Notice the different formats and invalid entries (e.g. 'N/A', 'not available', mixed date formats).

# %% [markdown]
# ### Q27. Replace text placeholders like 'N/A' and 'not available' in OrderDate with NaN.

# %% [markdown]
# ### Q28. Convert OrderDate to a proper datetime column using pd.to_datetime with errors='coerce' (this will turn any format pandas cannot understand, including invalid dates, into NaT).

# %% [markdown]
# ### Q29. Count how many rows have a missing/invalid OrderDate (NaT) after conversion.

# %% [markdown]
# ### Q30. Drop rows where OrderDate could not be converted (NaT).

# %% [markdown]
# ### Q31. Create new OrderYear and OrderMonth columns extracted from OrderDate.

# %% [markdown]
# ## Part E - Final Cleanup

# %% [markdown]
# ### Q32. Remove exact duplicate rows from the dataset.

# %% [markdown]
# ### Q33. Recheck missing values in every column to confirm the dataset is clean.

# %% [markdown]
# ### Q34. Reset the index of the cleaned dataframe.

# %% [markdown]
# ### Q35. Save the cleaned dataset as clean_retail_orders.csv.

# %% [markdown]
# ## Part F - Analysis

# %% [markdown]
# ### Q36. Find total Sales (Price * Quantity) for each order as a new column TotalAmount.

# %% [markdown]
# ### Q37. Find total Sales by ProductCategory.

# %% [markdown]
# ### Q38. Find total Sales by City.

# %% [markdown]
# ### Q39. Find the month with the highest total Sales.

# %% [markdown]
# ### Q40. Find average Rating by ProductCategory.

# %% [markdown]
# ## Part G - Matplotlib

# %% [markdown]
# ### Q41. Create a Bar Chart of total Sales by ProductCategory.

# %% [markdown]
# ### Q42. Create a Line Chart of monthly total Sales trend.

# %% [markdown]
# ### Q43. Create a Histogram of the Age column.

# %% [markdown]
# ### Q44. Create a Scatter Plot of Price vs Rating.

# %% [markdown]
# ### Q45. Create a Pie Chart of order share by PaymentMethod.

# %% [markdown]
# ## Part H - Seaborn

# %% [markdown]
# ### Q46. Create a Count Plot of ProductCategory.

# %% [markdown]
# ### Q47. Create a Box Plot of TotalAmount by ProductCategory.

# %% [markdown]
# ### Q48. Create a Bar Plot of average Rating by Region.

# %% [markdown]
# ### Q49. Create a Heatmap of correlation between numeric columns.

# %% [markdown]
# ### Q50. Create a Histogram with KDE for TotalAmount.
